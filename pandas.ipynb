# %%
5+2
# Out:
# 7

# %%
import pandas as pd

# %%
df=pd.read_csv('dd.csv')

# %%
df
# Out:
#             temp  date    q          e
# 0             55    16   32     Sunday
# 1             45    85   55  saturaday
# 2             12    22   52  Wednesday
# 3             82    55   66     monday
# 4             55     4  NaN     monday
# 5             77    33   -1     monday
# 6             21    33   22    Tuesday
# 7  not available    55  n.a     Sunday

# %%
df['temp'].max()
# Out:
# 'not available'

# %%
df['date'][df['temp']=='55']
# Out:
# 0    16
# 4     4
# Name: date, dtype: int64

# %%
df['q'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-586cfc904afe> in <module>
# ----> 1 df['q'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     561         dtype_count = dtype
#     562     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 563     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     564
#     565     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# before use the data we have to clean data.it is called as data manging or data wrangling

# %% [markdown]
# READY TO PROCESS

# %%
df.fillna(0,inplace=True)
df
# Out:
#             temp  date    q          e
# 0             55    16   32     Sunday
# 1             45    85   55  saturaday
# 2             12    22   52  Wednesday
# 3             82    55   66     monday
# 4             55     4    0     monday
# 5             77    33   -1     monday
# 6             21    33   22    Tuesday
# 7  not available    55  n.a     Sunday

# %%
df.shape
# Out:
# (8, 4)

# %%
r,c=df.shape

# %%
r
# Out:
# 8

# %%
c
# Out:
# 4

# %%
dic={
    'date':[1,2,3,4,5,6],
    'rain' :[22,33,55,15,76,55],
    'temp':[32.5,34.2,27,21,20.2,23],
}

# %%
dff=pd.DataFrame(dic)
dff
# Out:
#    date  rain  temp
# 0     1    22  32.5
# 1     2    33  34.2
# 2     3    55  27.0
# 3     4    15  21.0
# 4     5    76  20.2
# 5     6    55  23.0

# %%
dff.head()
# Out:
#    date  rain  temp
# 0     1    22  32.5
# 1     2    33  34.2
# 2     3    55  27.0
# 3     4    15  21.0
# 4     5    76  20.2

# %% [markdown]
# to print last five rows use tail()

# %%
dff.tail()
# Out:
#    date  rain  temp
# 1     2    33  34.2
# 2     3    55  27.0
# 3     4    15  21.0
# 4     5    76  20.2
# 5     6    55  23.0

# %%
dff.tail(1)
# Out:
#    date  rain  temp
# 5     6    55  23.0

# %%
dff.tail(2)
# Out:
#    date  rain  temp
# 4     5    76  20.2
# 5     6    55  23.0

# %%
dff.tail(2)['rain'].mean()
# Out:
# 65.5

# %%
dff.columns
# Out:
# Index(['date', 'rain', 'temp'], dtype='object')

# %%
dff['temp']
# Out:
# 0    32.5
# 1    34.2
# 2    27.0
# 3    21.0
# 4    20.2
# 5    23.0
# Name: temp, dtype: float64

# %%
dff[['date','temp']]
# Out:
#    date  temp
# 0     1  32.5
# 1     2  34.2
# 2     3  27.0
# 3     4  21.0
# 4     5  20.2
# 5     6  23.0

# %%
dff[['date','temp']].max()
# Out:
# date     6.0
# temp    34.2
# dtype: float64

# %% [markdown]
# to get the averange/mean use mean()
# to get the standard deviation use std()

# %%
dff[['date','temp']].std()
# Out:
# date    1.870829
# temp    5.958663
# dtype: float64

# %%
dff.describe()
# Out:
#            date       rain       temp
# count  6.000000   6.000000   6.000000
# mean   3.500000  42.666667  26.316667
# std    1.870829  23.243637   5.958663
# min    1.000000  15.000000  20.200000
# 25%    2.250000  24.750000  21.500000
# 50%    3.500000  44.000000  25.000000
# 75%    4.750000  55.000000  31.125000
# max    6.000000  76.000000  34.200000

# %%
dff[dff.temp>=25]
# Out:
#    date  rain  temp
# 0     1    22  32.5
# 1     2    33  34.2
# 2     3    55  27.0

# %%
dff[dff['temp']>=25]
# Out:
#    date  rain  temp
# 0     1    22  32.5
# 1     2    33  34.2
# 2     3    55  27.0

# %%
dff[dff['temp']==dff['temp'].max()]
# Out:
#    date  rain  temp
# 1     2    33  34.2

# %%
dff.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# to change index use set_index()

# %%
dff.set_index('date')
# Out:
#       rain  temp
# date
# 1       22  32.5
# 2       33  34.2
# 3       55  27.0
# 4       15  21.0
# 5       76  20.2
# 6       55  23.0

# %%
dff
# Out:
#    date  rain  temp
# 0     1    22  32.5
# 1     2    33  34.2
# 2     3    55  27.0
# 3     4    15  21.0
# 4     5    76  20.2
# 5     6    55  23.0

# %%
dff.set_index('date',inplace=True)

# %%
dff
# Out:
#       rain  temp
# date
# 1       22  32.5
# 2       33  34.2
# 3       55  27.0
# 4       15  21.0
# 5       76  20.2
# 6       55  23.0

# %%
df
# Out:
#             temp  date    q          e
# 0             55    16   32     Sunday
# 1             45    85   55  saturaday
# 2             12    22   52  Wednesday
# 3             82    55   66     monday
# 4             55     4    0     monday
# 5             77    33   -1     monday
# 6             21    33   22    Tuesday
# 7  not available    55  n.a     Sunday

# %%
df.loc[2]
# Out:
# temp           12
# date           22
# q              52
# e       Wednesday
# Name: 2, dtype: object

# %%
dff.reset_index(inplace=True)

# %%
dff
# Out:
#    index  date  rain  temp
# 0      0     1    22  32.5
# 1      1     2    33  34.2
# 2      2     3    55  27.0
# 3      3     4    15  21.0
# 4      4     5    76  20.2
# 5      5     6    55  23.0

# %% [markdown]
# Different Ways of creating dataframe \n
# 1.Using CSV \n
# 2.Using Excel \n
# 3.From python dictionary \n
# 4.From list of tuples \n
# 5.From list of dictories
# .

# %%
dfff=pd.read_excel("Book1.xlsx","Sheet1")

# %%
dfff
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  2016-01-01           38        23        52                 30.03
# 1  2016-01-02           36        18        46                 30.02
# 2  2016-01-03           40        21        47                 29.86
# 3  2016-01-04           25         9        44                 30.05
# 4  2016-01-05           20        -3        41                 30.57
# 5  2016-01-06           33         4        35                 30.50
# 6  2016-01-07           39        11        33                 30.28
# 7  2016-01-08           39        29        64                 30.20
# 8  2016-01-09           44        38        77                 30.16
# 9  2016-01-10           50        46        71                 29.59
# 10 2016-01-11           33         8        37                 29.92
# 11 2016-01-12           35        15        53                 29.85
# 12 2016-01-13           26         4        42                 29.94
# 13 2016-01-14           30        12        47                 29.95
# 14 2016-01-15           43        31        62                 29.82
# 15 2016-01-16           47        37        70                 29.52
# 16 2016-01-17           36        23        66                 29.78
# 17 2016-01-18           25         6        53                 29.83
# 18 2016-01-19           22         3        42                 30.03
# 19 2016-01-20           32        15        49                 30.13
# 20 2016-01-21           31        11        45                 30.15
# 21 2016-01-22           26         6        41                 30.21
# 22 2016-01-23           26        21        78                 29.77
# 23 2016-01-24           28        11        53                 29.92
# 24 2016-01-25           34        18        54                 30.25
# 25 2016-01-26           43        29        56                 30.03
# 26 2016-01-27           41        22        45                 30.03
# 27 2016-01-28           37        20        51                 29.90
# 28 2016-01-29           36        21        50                 29.58
# 29 2016-01-30           34        16        46                 30.01
# 30 2016-01-31           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
l=[
    (15,22,66),
    (8,25,55),
    (9,31,59),
    (65,14,44)
]
t=pd.DataFrame(l,columns=["date","temp","rain"])

# %%
t
# Out:
#    date  temp  rain
# 0    15    22    66
# 1     8    25    55
# 2     9    31    59
# 3    65    14    44

# %%
ld=[
    {'date':12,'rain':33,'temp':65},
    {'date':22,'rain':43,'temp':95},
    {'date':15,'rain':13,'temp':22},
    {'date':10,'rain':73,'temp':75},
]
g=pd.DataFrame(ld)
g
# Out:
#    date  rain  temp
# 0    12    33    65
# 1    22    43    95
# 2    15    13    22
# 3    10    73    75

# %% [markdown]
# in addition to that there are methods  read_hdf,read_sql,read_json,read_html

# %% [markdown]
# we can write read from files

# %%
df
# Out:
#             temp  date    q          e
# 0             55    16   32     Sunday
# 1             45    85   55  saturaday
# 2             12    22   52  Wednesday
# 3             82    55   66     monday
# 4             55     4    0     monday
# 5             77    33   -1     monday
# 6             21    33   22    Tuesday
# 7  not available    55  n.a     Sunday

# %%
df=pd.read_csv("dd.csv",skiprows=1)

# %%
df
# Out:
#               55  16   32     Sunday
# 0             45  85   55  saturaday
# 1             12  22   52  Wednesday
# 2             82  55   66     monday
# 3             55   4  NaN     monday
# 4             77  33   -1     monday
# 5             21  33   22    Tuesday
# 6  not available  55  n.a     Sunday

# %%
l=[
    (15,22,66),
    (8,25,55),
    (9,"n.a",59),
    (65,"not available",44)
]
h=pd.DataFrame(l,columns=["date","temp","rain"])

# %%
h
# Out:
#    date           temp  rain
# 0    15             22    66
# 1     8             25    55
# 2     9            n.a    59
# 3    65  not available    44

# %%
df=pd.read_csv('dd.csv')
df
# Out:
#             temp  date    q          e
# 0             55    16   32     Sunday
# 1             45    85   55  saturaday
# 2             12    22   52  Wednesday
# 3             82    55   66     monday
# 4             55     4  NaN     monday
# 5             77    33   -1     monday
# 6             21    33   22    Tuesday
# 7  not available    55  n.a     Sunday

# %%
df=pd.read_csv('dd.csv',na_values=["not available","n.a"])

# %%
df
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4   NaN     monday
# 5  77.0    33  -1.0     monday
# 6  21.0    33  22.0    Tuesday
# 7   NaN    55   NaN     Sunday

# %%
df=pd.read_csv('dd.csv')

# %%
df
# Out:
#             temp  date    q          e
# 0             55    16   32     Sunday
# 1             45    85   55  saturaday
# 2             12    22   52  Wednesday
# 3             82    55   66     monday
# 4             55     4  NaN     monday
# 5             77    33   -1     monday
# 6             21    33   22    Tuesday
# 7  not available    55  n.a     Sunday

# %%
df=pd.read_csv('dd.csv',na_values={
    "q":["not available","n.a",-1],
         "temp":["not available","n.a"]
         })

# %%
df
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4   NaN     monday
# 5  77.0    33   NaN     monday
# 6  21.0    33  22.0    Tuesday
# 7   NaN    55   NaN     Sunday

# %% [markdown]
# to write to csv file use to_csv()

# %%
df.to_csv("new.csv")

# %%
df.to_csv("newwithoutIndex.csv",index=False)

# %%
df.to_csv("newOnlysomeColumns",columns=['date','q'])

# %%
df.to_csv("newWithoutHeader.csv",header=False)

# %%
df=pd.read_csv('dd.csv')
df
# Out:
#             temp  date    q          e
# 0             55    16   32     Sunday
# 1             45    85   55  saturaday
# 2             12    22   52  Wednesday
# 3             82    55   66     monday
# 4             55     4  NaN     monday
# 5             77    33   -1     monday
# 6             21    33   22    Tuesday
# 7  not available    55  n.a     Sunday

# %%
def convert_q(cell):
    if cell=="n.a":
        return '00'
    return cell
df=pd.read_csv('dd.csv',converters={
    "q":convert_q
})
df
# Out:
#             temp  date   q          e
# 0             55    16  32     Sunday
# 1             45    85  55  saturaday
# 2             12    22  52  Wednesday
# 3             82    55  66     monday
# 4             55     4         monday
# 5             77    33  -1     monday
# 6             21    33  22    Tuesday
# 7  not available    55  00     Sunday

# %%
n={
    'name':{'0':'j','1':'g','2':"NaN"},
    'age':{'0':55,'1':27,'2':"NaN"},
}

# %%
o=pd.DataFrame(n)

# %%
o
# Out:
#   name  age
# 0    j   55
# 1    g   27
# 2  NaN  NaN

# %%
newdf=o.fillna({
    'name':'no name',
    'age':0
})

# %%
newdf
# Out:
#   name  age
# 0    j   55
# 1    g   27
# 2  NaN  NaN

# %%
df=pd.read_csv('dd.csv',na_values={
    "q":["not available","n.a",-1],
         "temp":["not available","n.a"]
         })

# %%
df
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4   NaN     monday
# 5  77.0    33   NaN     monday
# 6  21.0    33  22.0    Tuesday
# 7   NaN    55   NaN     Sunday

# %%
newdf=df.fillna({
    'temp':0,
    'q':'no q'
})

# %%
newdf
# Out:
#    temp  date     q          e
# 0  55.0    16    32     Sunday
# 1  45.0    85    55  saturaday
# 2  12.0    22    52  Wednesday
# 3  82.0    55    66     monday
# 4  55.0     4  no q     monday
# 5  77.0    33  no q     monday
# 6  21.0    33    22    Tuesday
# 7   0.0    55  no q     Sunday

# %%
hh=df.fillna(method="ffill")
hh
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4  66.0     monday
# 5  77.0    33  66.0     monday
# 6  21.0    33  22.0    Tuesday
# 7  21.0    55  22.0     Sunday

# %%
hh=df.fillna(method="bfill")
hh
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4  22.0     monday
# 5  77.0    33  22.0     monday
# 6  21.0    33  22.0    Tuesday
# 7   NaN    55   NaN     Sunday

# %% [markdown]
# in thi bfill and ffbill methods copying values vertically.but by setting argument axis="columns"  can copy values horzontally

# %%
hh=df.fillna(method="ffill",axis="columns")
hh
# Out:
#   temp date   q          e
# 0   55   16  32     Sunday
# 1   45   85  55  saturaday
# 2   12   22  52  Wednesday
# 3   82   55  66     monday
# 4   55    4   4     monday
# 5   77   33  33     monday
# 6   21   33  22    Tuesday
# 7  NaN   55  55     Sunday

# %%
hh=df.fillna(method="ffill",limit=1)
hh
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4  66.0     monday
# 5  77.0    33   NaN     monday
# 6  21.0    33  22.0    Tuesday
# 7  21.0    55  22.0     Sunday

# %%
df.interpolate()
##better guess for NaN values
# Out:
#    temp  date          q          e
# 0  55.0    16  32.000000     Sunday
# 1  45.0    85  55.000000  saturaday
# 2  12.0    22  52.000000  Wednesday
# 3  82.0    55  66.000000     monday
# 4  55.0     4  51.333333     monday
# 5  77.0    33  36.666667     monday
# 6  21.0    33  22.000000    Tuesday
# 7  21.0    55  22.000000     Sunday

# %%
df.interpolate(method="time")##work with only datetime value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-b398a4932dc4> in <module>
# ----> 1 df.interpolate(method="time")##work with only datetime value
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6868                 "those NaNs before interpolating."
#    6869             )
# -> 6870         new_data = obj._mgr.interpolate(
#    6871             method=method,
#    6872             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     559
#     560     def interpolate(self, **kwargs) -> "BlockManager":
# --> 561         return self.apply("interpolate", **kwargs)
#     562
#     563     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#    1128         assert index is not None  # for mypy
#    1129
# -> 1130         return self._interpolate(
#    1131             method=m,
#    1132             index=index,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _interpolate(self, method, index, fill_value, axis, limit, limit_direction, limit_area, inplace, downcast, **kwargs)
#    1231
#    1232         # interp each column independently
# -> 1233         interp_values = np.apply_along_axis(func, axis, data)
#    1234
#    1235         blocks = [self.make_block_same_class(interp_values)]
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377             'Cannot apply_along_axis when any iteration dimensions are 0'
#     378         ) from None
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in func(yvalues)
#    1218             # should the axis argument be handled below in apply_along_axis?
#    1219             # i.e. not an arg to missing.interpolate_1d
# -> 1220             return missing.interpolate_1d(
#    1221                 xvalues=index,
#    1222                 yvalues=yvalues,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in interpolate_1d(xvalues, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, **kwargs)
#     204         if not getattr(xvalues, "is_all_dates", None):
#     205             # if not issubclass(xvalues.dtype.type, np.datetime64):
# --> 206             raise ValueError(
#     207                 "time-weighted interpolation only works "
#     208                 "on Series or DataFrames with a "
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %%
df.dropna()
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 6  21.0    33  22.0    Tuesday

# %%
df.dropna(how="all")## for drop row all data should be NaN
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4   NaN     monday
# 5  77.0    33   NaN     monday
# 6  21.0    33  22.0    Tuesday
# 7   NaN    55   NaN     Sunday

# %%
df.dropna(thresh=2)## i want two minimum valid data to keep the row
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4   NaN     monday
# 5  77.0    33   NaN     monday
# 6  21.0    33  22.0    Tuesday
# 7   NaN    55   NaN     Sunday

# %%
## for replace invalid values
import numpy as np
newdf=df.replace(-99999,np.NaN)

# %%
newdf=df.replace([-99999,-88888],np.NaN)

# %%
newdf=df.replace({
    'date':99999
},np.NaN)

# %%
newdf=df.replace({
    9999:np.NaN,
    "invalid":"sunny"
    
})

# %%
r=pd.read_csv("dd.csv")
r=pd.read_csv('dd.csv',na_values={
    "q":["not available","n.a",-1],
         "temp":["not available","n.a"]
         })
r.fillna(0,inplace=True)
r
# Out:
#    temp  date     q          e
# 0  55.0    16  32.0     Sunday
# 1  45.0    85  55.0  saturaday
# 2  12.0    22  52.0  Wednesday
# 3  82.0    55  66.0     monday
# 4  55.0     4   0.0     monday
# 5  77.0    33   0.0     monday
# 6  21.0    33  22.0    Tuesday
# 7   0.0    55   0.0     Sunday

# %%
p=r.groupby('e')
p

# %%
for x,y in p:
    print(x)
    print(y)
# Out:
# Sunday
#    temp  date     q       e
# 0  55.0    16  32.0  Sunday
# 7   0.0    55   0.0  Sunday
# Tuesday
#    temp  date     q        e
# 6  21.0    33  22.0  Tuesday
# Wednesday
#    temp  date     q          e
# 2  12.0    22  52.0  Wednesday
# monday
#    temp  date     q       e
# 3  82.0    55  66.0  monday
# 4  55.0     4   0.0  monday
# 5  77.0    33   0.0  monday
# saturaday
#    temp  date     q          e
# 1  45.0    85  55.0  saturaday

# %%
p.get_group('monday')
# Out:
#    temp  date     q       e
# 3  82.0    55  66.0  monday
# 4  55.0     4   0.0  monday
# 5  77.0    33   0.0  monday

# %%
p.mean()
# Out:
#                 temp       date     q
# e
# Sunday     27.500000  35.500000  16.0
# Tuesday    21.000000  33.000000  22.0
# Wednesday  12.000000  22.000000  52.0
# monday     71.333333  30.666667  22.0
# saturaday  45.000000  85.000000  55.0

# %%
p.max()
# Out:
#            temp  date     q
# e
# Sunday     55.0    55  32.0
# Tuesday    21.0    33  22.0
# Wednesday  12.0    22  52.0
# monday     82.0    55  66.0
# saturaday  45.0    85  55.0

# %%
p.describe()
# Out:
#            temp                                                        date  \
#           count       mean        std   min    25%   50%    75%   max count
# e
# Sunday      2.0  27.500000  38.890873   0.0  13.75  27.5  41.25  55.0   2.0
# Tuesday     1.0  21.000000        NaN  21.0  21.00  21.0  21.00  21.0   1.0
# Wednesday   1.0  12.000000        NaN  12.0  12.00  12.0  12.00  12.0   1.0
# monday      3.0  71.333333  14.364308  55.0  66.00  77.0  79.50  82.0   3.0
# saturaday   1.0  45.000000        NaN  45.0  45.00  45.0  45.00  45.0   1.0
#
#                       ...                  q                               \
#                 mean  ...    75%   max count  mean        std   min   25%
# e                     ...
# Sunday     35.500000  ...  45.25  55.0   2.0  16.0  22.627417   0.0   8.0
# Tuesday    33.000000  ...  33.00  33.0   1.0  22.0        NaN  22.0  22.0
# Wednesday  22.000000  ...  22.00  22.0   1.0  52.0        NaN  52.0  52.0
# monday     30.666667  ...  44.00  55.0   3.0  22.0  38.105118   0.0   0.0
# saturaday  85.000000  ...  85.00  85.0   1.0  55.0        NaN  55.0  55.0
#
#
#             50%   75%   max
# e
# Sunday     16.0  24.0  32.0
# Tuesday    22.0  22.0  22.0
# Wednesday  52.0  52.0  52.0
# monday      0.0  33.0  66.0
# saturaday  55.0  55.0  55.0
#
# [5 rows x 24 columns]

# %%
# %matplotlib inline
p.plot()
# Out:
# e
# Sunday       AxesSubplot(0.125,0.125;0.775x0.755)
# Tuesday      AxesSubplot(0.125,0.125;0.775x0.755)
# Wednesday    AxesSubplot(0.125,0.125;0.775x0.755)
# monday       AxesSubplot(0.125,0.125;0.775x0.755)
# saturaday    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
ld=[
    {'date':'monday','chicago':33,'berlin':65},
    {'date':'tuesday','chicago':42,'berlin':64},
    {'date':'wednesday','chicago':13,'berlin':75},
    {'date':'friday','chicago':123,'berlin':5},
]
g=pd.DataFrame(ld)
g
# Out:
#         date  chicago  berlin
# 0     monday       33      65
# 1    tuesday       42      64
# 2  wednesday       13      75
# 3     friday      123       5

# %%
df=pd.melt(g,id_vars=["date"])
df
# Out:
#         date variable  value
# 0     monday  chicago     33
# 1    tuesday  chicago     42
# 2  wednesday  chicago     13
# 3     friday  chicago    123
# 4     monday   berlin     65
# 5    tuesday   berlin     64
# 6  wednesday   berlin     75
# 7     friday   berlin      5

# %%
df=pd.melt(g,id_vars=["date"])
df[df["variable"]=="chicago"]
# Out:
#         date variable  value
# 0     monday  chicago     33
# 1    tuesday  chicago     42
# 2  wednesday  chicago     13
# 3     friday  chicago    123

# %%
df=pd.melt(g,id_vars=["date"],var_name="city")
df
# Out:
#         date     city  value
# 0     monday  chicago     33
# 1    tuesday  chicago     42
# 2  wednesday  chicago     13
# 3     friday  chicago    123
# 4     monday   berlin     65
# 5    tuesday   berlin     64
# 6  wednesday   berlin     75
# 7     friday   berlin      5

# %%
dic={
    'city':['bali','indo','gree','hiji','kuli','miti'],
    'rain' :[22,33,55,15,76,55],
    'temp':[32.5,34.2,27,21,20.2,23],
}
g=pd.DataFrame(dic)
g
# Out:
#    city  rain  temp
# 0  bali    22  32.5
# 1  indo    33  34.2
# 2  gree    55  27.0
# 3  hiji    15  21.0
# 4  kuli    76  20.2
# 5  miti    55  23.0

# %%
di={
    'city':['athns','oia','mitiyora','acropolises','jiji','kkii'],
    'rain' :[22,33,55,15,76,55],
    'temp':[32.5,34.2,27,21,20.2,23],
}
k=pd.DataFrame(dic)
k
# Out:
#    city  rain  temp
# 0  bali    22  32.5
# 1  indo    33  34.2
# 2  gree    55  27.0
# 3  hiji    15  21.0
# 4  kuli    76  20.2
# 5  miti    55  23.0

# %% [markdown]
# to concat two dataframes

# %%
i=pd.concat([g,k])
i
# Out:
#    city  rain  temp
# 0  bali    22  32.5
# 1  indo    33  34.2
# 2  gree    55  27.0
# 3  hiji    15  21.0
# 4  kuli    76  20.2
# 5  miti    55  23.0
# 0  bali    22  32.5
# 1  indo    33  34.2
# 2  gree    55  27.0
# 3  hiji    15  21.0
# 4  kuli    76  20.2
# 5  miti    55  23.0

# %%
i=pd.concat([g,k],keys=["indo","greek"])
i
# Out:
#          city  rain  temp
# indo  0  bali    22  32.5
#       1  indo    33  34.2
#       2  gree    55  27.0
#       3  hiji    15  21.0
#       4  kuli    76  20.2
#       5  miti    55  23.0
# greek 0  bali    22  32.5
#       1  indo    33  34.2
#       2  gree    55  27.0
#       3  hiji    15  21.0
#       4  kuli    76  20.2
#       5  miti    55  23.0

# %%
i.loc['indo']
# Out:
#    city  rain  temp
# 0  bali    22  32.5
# 1  indo    33  34.2
# 2  gree    55  27.0
# 3  hiji    15  21.0
# 4  kuli    76  20.2
# 5  miti    55  23.0
